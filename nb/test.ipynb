# %%
num = [1, 5, 2, 0]
num
num.append('22')
num
val = num[-1]
val

s = {'1' : '10', '1': '20', '2': '30', '3': '40', '4': '50', '5': '60'}
s
# Out:
# {'1': '20', '2': '30', '3': '40', '4': '50', '5': '60'}
